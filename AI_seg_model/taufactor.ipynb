# %%
import porespy as ps
import matplotlib.pyplot as plt
import tifffile
import taufactor
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       1 import porespy as ps
#       2 import matplotlib.pyplot as plt
#       3 import tifffile
# ----> 4 import taufactor
#
# ModuleNotFoundError: No module named 'taufactor'

# %%
img1 = tifffile.imread("runs/segment/FIB_3D_SEM_LFP_Gauss_Seg.tiff")
print(ps.metrics.phase_fraction(img1))
print(ps.metrics.pore_size_distribution(img1))

plt.imshow(img1)
plt.show()
