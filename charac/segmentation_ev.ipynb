# %%
from skimage.filters import threshold_otsu, threshold_sauvola
from sklearn.metrics import accuracy_score, precision_score, recall_score, jaccard_score
import tifffile as tiff

# %%
# Otsu
image = tiff.imread(r"C:\PhD_programs\Code\meizeddin_PhD_code\AI_seg_model\sem_data\LFP_FIB_SEM_Crop.tiff")

threshold = threshold_otsu(image)
otsu_mask = image > threshold

# Sauvola
threshold = threshold_sauvola(image, window_size=25)
sauvola_mask = image > threshold

# %%
y_true = ground_truth.flatten()
y_pred = otsu_mask.flatten()

accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)
iou = jaccard_score(y_true, y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 y_true = ground_truth.flatten()
#       2 y_pred = otsu_mask.flatten()
#       3
#       4 accuracy = accuracy_score(y_true, y_pred)
#
# NameError: name 'ground_truth' is not defined
